# %%
# Environment & Config Check

This notebook verifies that the virtual environment, environment variables, and core libraries are properly configured.
# Out:
#   Cell In[1], line 3
#     This notebook verifies that the virtual environment, environment variables, and core libraries are properly configured.
#          ^
# SyntaxError: invalid syntax

# %%
from pathlib import Path
import sys, os
import numpy as np
from dotenv import load_dotenv

# Locate project root relative to notebooks/ folder
ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()

# Load environment variables from .env
load_dotenv(ROOT / ".env")
print(".env loaded successfully.")

# %%
# Check for API_KEY and DATA_DIR
api_key = os.getenv("API_KEY")
data_dir = os.getenv("DATA_DIR")

print(f"API_KEY present: {api_key is not None}")
print(f"Loaded DATA_DIR: {data_dir}")

# %%
# NumPy mini-demo
arr = np.array([1, 2, 3, 4, 5])
print("Array:", arr)
print("Mean:", arr.mean())
print("Vectorized * 10:", arr * 10)
